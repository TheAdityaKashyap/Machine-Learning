# %%
import math
# Sigmoid turns z into a chance (O to 1)
def sigmoid(z) :
return 1 / (1 +
hours = 5
z = —1.5 + 0.6 * hours # Formula
chance = sigmoid (z)
# Get chance
predi on
= "Pass" if chance > else "Fail" # Decide
of passing: {chance: .2f} (that's
pri nt ction: {prediction}" )
.0096) " )
# Out:
#   Cell In[1], line 6
#     z = —1.5 + 0.6 * hours # Formula
#         ^
# SyntaxError: invalid character '—' (U+2014)
